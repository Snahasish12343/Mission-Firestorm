# %% [markdown]
# ## Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
scores = np.array([45, 55, 60, 65, 70, 72, 75, 77, 78, 79, 80, 82, 85, 88, 90, 92, 95])
plt.hist(scores,bins=10, color='purple', edgecolor='Black')
plt.show()

# %%
scores = np.array.normal()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 scores = np.array.normal()
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'normal'
